# %%
import pandas as pd

# %%
df = pd.read_csv("tested2.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0          892.0         0       3
# 1          893.0         1       3
# 2          894.0         0       2
# 3          895.0         0       3
# 4          896.0         1       3
# ..           ...       ...     ...
# 413       1305.0         0       3
# 414       1306.0         1       1
# 415       1307.0         0       3
# 416       1308.0         0       3
# 417       1309.0         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                                             NaN    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male   NaN      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0        892.0         0       3
# 1        893.0         1       3
# 2        894.0         0       2
# 3        895.0         0       3
# 4        896.0         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                                           NaN    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male   NaN      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3      NaN   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413       1305.0         0       3            Spector, Mr. Woolf    male
# 414       1306.0         1       1  Oliva y Ocana, Dona. Fermina  female
# 415       1307.0         0       3  Saether, Mr. Simon Sivertsen    male
# 416       1308.0         0       3           Ware, Mr. Frederick    male
# 417       1309.0         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0        892.0         0       3                  Kelly, Mr. James    male
# 1        893.0         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2        894.0         0       2                               NaN    male
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S
# 2  62.0      0      0  240276  9.6875   NaN        Q

# %%
df.tail(4)
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 414       1306.0         1       1  Oliva y Ocana, Dona. Fermina  female
# 415       1307.0         0       3  Saether, Mr. Simon Sivertsen    male
# 416       1308.0         0       3           Ware, Mr. Frederick    male
# 417       1309.0         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   417.000000  418.000000  418.000000  331.000000  418.000000
# mean   1100.988010    0.363636    2.265550   30.282477    0.447368
# std     120.542373    0.481622    0.841838   14.201534    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     997.000000    0.000000    1.000000   21.000000    0.000000
# 50%    1101.000000    0.000000    3.000000   27.000000    0.000000
# 75%    1205.000000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False   True  False  False  False  False   False
# 3          False     False   False  False  False   True  False  False    True
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 413        False     False   False  False  False   True  False  False   False
# 414        False     False   False  False  False  False  False  False   False
# 415        False     False   False  False  False  False  False  False   False
# 416        False     False   False  False  False   True  False  False   False
# 417        False     False   False  False  False   True  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df.notnull()
# Out:
#      PassengerId  Survived  Pclass   Name   Sex    Age  SibSp  Parch  Ticket  \
# 0           True      True    True   True  True   True   True   True    True
# 1           True      True    True   True  True   True   True   True    True
# 2           True      True    True  False  True   True   True   True    True
# 3           True      True    True   True  True  False   True   True   False
# 4           True      True    True   True  True   True   True   True    True
# ..           ...       ...     ...    ...   ...    ...    ...    ...     ...
# 413         True      True    True   True  True  False   True   True    True
# 414         True      True    True   True  True   True   True   True    True
# 415         True      True    True   True  True   True   True   True    True
# 416         True      True    True   True  True  False   True   True    True
# 417         True      True    True   True  True  False   True   True    True
#
#      Fare  Cabin  Embarked
# ...

# %%
df['PassengerId']
# Out:
# 0       892.0
# 1       893.0
# 2       894.0
# 3       895.0
# 4       896.0
#         ...
# 413    1305.0
# 414    1306.0
# 415    1307.0
# 416    1308.0
# 417    1309.0
# Name: PassengerId, Length: 418, dtype: float64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=418, step=1)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.dtypes
# Out:
# PassengerId    float64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df.head(3)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0        892.0         0       3                  Kelly, Mr. James    male
# 1        893.0         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2        894.0         0       2                               NaN    male
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S
# 2  62.0      0      0  240276  9.6875   NaN        Q

# %%
df.loc[[21,23,34,65,77],:]
# Out:
#     PassengerId  Survived  Pclass  \
# 21        913.0         0       3
# 23        915.0         0       1
# 34        926.0         0       1
# 65        957.0         1       2
# 77        969.0         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 21                          Olsen, Master. Artur Karl    male   9.0      0
# 23                    Williams, Mr. Richard Norris II    male  21.0      0
# 34                           Mock, Mr. Philipp Edmund    male  30.0      1
# 65  Corey, Mrs. Percy C (Mary Phyllis Elizabeth Mi...  female   NaN      0
# 77  Cornell, Mrs. Robert Clifford (Malvina Helen L...  female  55.0      2
#
#     Parch        Ticket     Fare Cabin Embarked
# 21      1       C 17368   3.1708   NaN        S
# 23      1      PC 17597  61.3792   NaN        C
# 34      0         13236  57.7500   C78        C
# 65      0  F.C.C. 13534  21.0000   NaN        S
# 77      0         11770  25.7000  C101        S

# %%
df.loc[23:32]
# Out:
#     PassengerId  Survived  Pclass  \
# 23        915.0         0       1
# 24        916.0         1       1
# 25        917.0         0       3
# 26        918.0         1       1
# 27        919.0         0       3
# 28        920.0         0       1
# 29        921.0         0       3
# 30        922.0         0       2
# 31        923.0         0       2
# 32        924.0         1       3
#
#                                                Name     Sex   Age  SibSp  \
# 23                  Williams, Mr. Richard Norris II    male  21.0      0
# 24  Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 25                          Robins, Mr. Alexander A    male  50.0      1
# 26                     Ostby, Miss. Helene Ragnhild  female  22.0      0
# 27                                Daher, Mr. Shedid    male  22.5      0
# 28                          Brady, Mr. John Bertram    male  41.0      0
# ...

# %%
df.loc[10: :5]
# Out:
#      PassengerId  Survived  Pclass  \
# 10         902.0         0       3
# 15         907.0         1       2
# 20         912.0         0       1
# 25         917.0         0       3
# 30         922.0         0       2
# ..           ...       ...     ...
# 395       1287.0         1       1
# 400       1292.0         1       1
# 405       1297.0         0       2
# 410       1302.0         1       3
# 415       1307.0         0       3
#
#                                                Name     Sex   Age  SibSp  \
# 10                                 Ilieff, Mr. Ylio    male   NaN      0
# 15    del Carlo, Mrs. Sebastiano (Argenia Genovesi)  female  24.0      1
# 20                           Rothschild, Mr. Martin    male  55.0      1
# 25                          Robins, Mr. Alexander A    male  50.0      1
# 30                     Louch, Mr. Charles Alexander    male  50.0      1
# ..                                              ...     ...   ...    ...
# ...

# %%
df.loc[[12,23,34,56,76,87],['PassengerId','Name','Sex','Age','Ticket']]
# Out:
#     PassengerId                                           Name     Sex   Age  \
# 12        904.0  Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0
# 23        915.0                Williams, Mr. Richard Norris II    male  21.0
# 34        926.0                       Mock, Mr. Philipp Edmund    male  30.0
# 56        948.0                                Cor, Mr. Bartol    male  35.0
# 76        968.0                               Miles, Mr. Frank    male   NaN
# 87        979.0                     Badman, Miss. Emily Louisa  female  18.0
#
#        Ticket
# 12      21228
# 23   PC 17597
# 34      13236
# 56     349230
# 76     359306
# 87  A/4 31416

# %%
df.loc[df['Age']>40]
# Out:
#      PassengerId  Survived  Pclass  \
# 1          893.0         1       3
# 2          894.0         0       2
# 11         903.0         0       1
# 13         905.0         0       2
# 14         906.0         1       1
# ..           ...       ...     ...
# 391       1283.0         1       1
# 393       1285.0         0       2
# 397       1289.0         1       1
# 404       1296.0         0       1
# 407       1299.0         0       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1                     Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                                                  NaN    male  62.0      0
# 11                          Jones, Mr. Charles Cresson    male  46.0      0
# 13                                Howard, Mr. Benjamin    male  63.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.loc[df['Sex']=='female']
# Out:
#      PassengerId  Survived  Pclass  \
# 1          893.0         1       3
# 4          896.0         1       3
# 6          898.0         1       3
# 8          900.0         1       3
# 12         904.0         1       1
# ..           ...       ...     ...
# 409       1301.0         1       3
# 410       1302.0         1       3
# 411       1303.0         1       1
# 412       1304.0         1       3
# 414       1306.0         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 4       Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1
# 6                               Connolly, Miss. Kate  female  30.0      0
# 8          Abrahim, Mrs. Joseph (Sophie Halaut Easu)  female  18.0      0
# 12     Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# ..                                               ...     ...   ...    ...
# ...

# %%
df.T
# Out:
#                           0                                 1       2    \
# PassengerId             892.0                             893.0   894.0
# Survived                    0                                 1       0
# Pclass                      3                                 3       2
# Name         Kelly, Mr. James  Wilkes, Mrs. James (Ellen Needs)     NaN
# Sex                      male                            female    male
# Age                      34.5                              47.0    62.0
# SibSp                       0                                 1       0
# Parch                       0                                 0       0
# Ticket                 330911                            363272  240276
# Fare                   7.8292                               7.0  9.6875
# Cabin                     NaN                               NaN     NaN
# Embarked                    Q                                 S       Q
#
# ...

# %%
df.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0        892.0         0       3
# 1        893.0         1       3
# 2        894.0         0       2
# 3        895.0         0       3
# 4        896.0         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                                           NaN    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male   NaN      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3      NaN   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0        892.0         0       3
# 1        893.0         1       3
# 2        894.0         0       2
# 3        895.0         0       3
# 4        896.0         1       3
# 5          NaN         0       3
# 6        898.0         1       3
# 7        899.0         0       2
# 8        900.0         1       3
# 9        901.0         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                                           NaN    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male   NaN      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin     NaN  14.0      0      0
# ...

# %%
df['Name'][2]='RAHUL DADGE'
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_7316\2889221320.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Name'][2]='RAHUL DADGE'

# %%
df.head(4)
# Out:
#    PassengerId  Survived  Pclass                              Name     Sex  \
# 0        892.0         0       3                  Kelly, Mr. James    male
# 1        893.0         1       3  Wilkes, Mrs. James (Ellen Needs)  female
# 2        894.0         0       2                       RAHUL DADGE    male
# 3        895.0         0       3                  Wirz, Mr. Albert    male
#
#     Age  SibSp  Parch  Ticket    Fare Cabin Embarked
# 0  34.5      0      0  330911  7.8292   NaN        Q
# 1  47.0      1      0  363272  7.0000   NaN        S
# 2  62.0      0      0  240276  9.6875   NaN        Q
# 3   NaN      0      0     NaN  8.6625   NaN        S

# %%
df.head(5).T
# Out:
#                             0                                 1            2  \
# PassengerId             892.0                             893.0        894.0
# Survived                    0                                 1            0
# Pclass                      3                                 3            2
# Name         Kelly, Mr. James  Wilkes, Mrs. James (Ellen Needs)  RAHUL DADGE
# Sex                      male                            female         male
# Age                      34.5                              47.0         62.0
# SibSp                       0                                 1            0
# Parch                       0                                 0            0
# Ticket                 330911                            363272       240276
# Fare                   7.8292                               7.0       9.6875
# Cabin                     NaN                               NaN          NaN
# ...

# %%
df2 = df[2:7].copy()

# %%
df2
# Out:
#    PassengerId  Survived  Pclass  \
# 2        894.0         0       2
# 3        895.0         0       3
# 4        896.0         1       3
# 5          NaN         0       3
# 6        898.0         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 2                                   RAHUL DADGE    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male   NaN      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                    Svensson, Mr. Johan Cervin     NaN  14.0      0      0
# 6                          Connolly, Miss. Kate  female  30.0      0      0
#
#     Ticket     Fare Cabin Embarked
# 2   240276   9.6875   NaN        Q
# 3      NaN   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S
# 5     7538   9.2250   NaN        S
# 6   330972   7.6292   NaN        Q

# %%
df2.index
# Out:
# RangeIndex(start=2, stop=7, step=1)

# %%
df2.iloc[[2,4],[0,3,4]]
# Out:
#    PassengerId                                          Name     Sex
# 4        896.0  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
# 6        898.0                          Connolly, Miss. Kate  female

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   417.000000  418.000000  418.000000  331.000000  418.000000
# mean   1100.988010    0.363636    2.265550   30.282477    0.447368
# std     120.542373    0.481622    0.841838   14.201534    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     997.000000    0.000000    1.000000   21.000000    0.000000
# 50%    1101.000000    0.000000    3.000000   27.000000    0.000000
# 75%    1205.000000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
df2['Name'][4] = "Poonam"
# Out:
# C:\Users\rahul\AppData\Local\Temp\ipykernel_7316\3323069403.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['Name'][4] = "Poonam"

# %%
df2
# Out:
#    PassengerId  Survived  Pclass                        Name     Sex   Age  \
# 2        894.0         0       2                 RAHUL DADGE    male  62.0
# 3        895.0         0       3            Wirz, Mr. Albert    male   NaN
# 4        896.0         1       3                      Poonam  female  22.0
# 5          NaN         0       3  Svensson, Mr. Johan Cervin     NaN  14.0
# 6        898.0         1       3        Connolly, Miss. Kate  female  30.0
#
#    SibSp  Parch   Ticket     Fare Cabin Embarked
# 2      0      0   240276   9.6875   NaN        Q
# 3      0      0      NaN   8.6625   NaN        S
# 4      1      1  3101298  12.2875   NaN        S
# 5      0      0     7538   9.2250   NaN        S
# 6      0      0   330972   7.6292   NaN        Q

# %%
df2.T
# Out:
#                        2                 3        4  \
# PassengerId        894.0             895.0    896.0
# Survived               0                 0        1
# Pclass                 2                 3        3
# Name         RAHUL DADGE  Wirz, Mr. Albert   Poonam
# Sex                 male              male   female
# Age                 62.0               NaN     22.0
# SibSp                  0                 0        1
# Parch                  0                 0        1
# Ticket            240276               NaN  3101298
# Fare              9.6875            8.6625  12.2875
# Cabin                NaN               NaN      NaN
# Embarked               Q                 S        S
#
#                                       5                     6
# PassengerId                         NaN                 898.0
# Survived                              0                     1
# Pclass                                3                     3
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0        892.0         0       3
# 1        893.0         1       3
# 2        894.0         0       2
# 3        895.0         0       3
# 4        896.0         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                                   RAHUL DADGE    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male   NaN      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3      NaN   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'
