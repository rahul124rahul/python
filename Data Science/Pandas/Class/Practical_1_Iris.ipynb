# %% [markdown]
# # Practical No 1

# %%
import pandas as pd

# %%
df = pd.read_csv("iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.index
# Out:
# RangeIndex(start=0, stop=150, step=1)

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.shape
# Out:
# (150, 6)

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.columns.values
# Out:
# array(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm',
#        'PetalWidthCm', 'Species'], dtype=object)

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
df.describe(include="all")
# Out:
#                 Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# count   150.000000     150.000000    150.000000     150.000000    150.000000
# unique         NaN            NaN           NaN            NaN           NaN
# top            NaN            NaN           NaN            NaN           NaN
# freq           NaN            NaN           NaN            NaN           NaN
# mean     75.500000       5.843333      3.054000       3.758667      1.198667
# std      43.445368       0.828066      0.433594       1.764420      0.763161
# min       1.000000       4.300000      2.000000       1.000000      0.100000
# 25%      38.250000       5.100000      2.800000       1.600000      0.300000
# 50%      75.500000       5.800000      3.000000       4.350000      1.300000
# 75%     112.750000       6.400000      3.300000       5.100000      1.800000
# max     150.000000       7.900000      4.400000       6.900000      2.500000
#
#             Species
# count           150
# ...

# %%
# df.describe()

# %%
df.head(n=3)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa

# %%
df["Species"]
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
df["Id"]
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 145    146
# 146    147
# 147    148
# 148    149
# 149    150
# Name: Id, Length: 150, dtype: int64

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#             Species  SepalWidthCm  SepalLengthCm  PetalWidthCm  PetalLengthCm  \
# 0       Iris-setosa           3.5            5.1           0.2            1.4
# 1       Iris-setosa           3.0            4.9           0.2            1.4
# 2       Iris-setosa           3.2            4.7           0.2            1.3
# 3       Iris-setosa           3.1            4.6           0.2            1.5
# 4       Iris-setosa           3.6            5.0           0.2            1.4
# ..              ...           ...            ...           ...            ...
# 145  Iris-virginica           3.0            6.7           2.3            5.2
# 146  Iris-virginica           2.5            6.3           1.9            5.0
# 147  Iris-virginica           3.0            6.5           2.0            5.2
# 148  Iris-virginica           3.4            6.2           2.3            5.4
# 149  Iris-virginica           3.0            5.9           1.8            5.1
#
#       Id
# 0      1
# 1      2
# ...

# %%
df.sort_index(axis=0,ascending=False)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 149  150            5.9           3.0            5.1           1.8
# 148  149            6.2           3.4            5.4           2.3
# 147  148            6.5           3.0            5.2           2.0
# 146  147            6.3           2.5            5.0           1.9
# 145  146            6.7           3.0            5.2           2.3
# ..   ...            ...           ...            ...           ...
# 4      5            5.0           3.6            1.4           0.2
# 3      4            4.6           3.1            1.5           0.2
# 2      3            4.7           3.2            1.3           0.2
# 1      2            4.9           3.0            1.4           0.2
# 0      1            5.1           3.5            1.4           0.2
#
#             Species
# 149  Iris-virginica
# 148  Iris-virginica
# 147  Iris-virginica
# 146  Iris-virginica
# 145  Iris-virginica
# ..              ...
# ...

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.sort_values(by="SepalLengthCm")
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 13    14            4.3           3.0            1.1           0.1
# 42    43            4.4           3.2            1.3           0.2
# 38    39            4.4           3.0            1.3           0.2
# 8      9            4.4           2.9            1.4           0.2
# 41    42            4.5           2.3            1.3           0.3
# ..   ...            ...           ...            ...           ...
# 122  123            7.7           2.8            6.7           2.0
# 118  119            7.7           2.6            6.9           2.3
# 117  118            7.7           3.8            6.7           2.2
# 135  136            7.7           3.0            6.1           2.3
# 131  132            7.9           3.8            6.4           2.0
#
#             Species
# 13      Iris-setosa
# 42      Iris-setosa
# 38      Iris-setosa
# 8       Iris-setosa
# 41      Iris-setosa
# ..              ...
# ...

# %%
df.sort_values(by="SepalWidthCm")
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 60    61            5.0           2.0            3.5           1.0
# 62    63            6.0           2.2            4.0           1.0
# 119  120            6.0           2.2            5.0           1.5
# 68    69            6.2           2.2            4.5           1.5
# 41    42            4.5           2.3            1.3           0.3
# ..   ...            ...           ...            ...           ...
# 16    17            5.4           3.9            1.3           0.4
# 14    15            5.8           4.0            1.2           0.2
# 32    33            5.2           4.1            1.5           0.1
# 33    34            5.5           4.2            1.4           0.2
# 15    16            5.7           4.4            1.5           0.4
#
#              Species
# 60   Iris-versicolor
# 62   Iris-versicolor
# 119   Iris-virginica
# 68   Iris-versicolor
# 41       Iris-setosa
# ..               ...
# ...

# %%
df.iloc[7]
# Out:
# Id                         8
# SepalLengthCm            5.0
# SepalWidthCm             3.4
# PetalLengthCm            1.5
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 7, dtype: object

# %%
df.iloc[2:7]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa

# %%
df.iloc[12:34:4]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 12  13            4.8           3.0            1.4           0.1  Iris-setosa
# 16  17            5.4           3.9            1.3           0.4  Iris-setosa
# 20  21            5.4           3.4            1.7           0.2  Iris-setosa
# 24  25            4.8           3.4            1.9           0.2  Iris-setosa
# 28  29            5.2           3.4            1.4           0.2  Iris-setosa
# 32  33            5.2           4.1            1.5           0.1  Iris-setosa

# %%
# df[12:29]

# %%
df[12:34:3]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 12  13            4.8           3.0            1.4           0.1  Iris-setosa
# 15  16            5.7           4.4            1.5           0.4  Iris-setosa
# 18  19            5.7           3.8            1.7           0.3  Iris-setosa
# 21  22            5.1           3.7            1.5           0.4  Iris-setosa
# 24  25            4.8           3.4            1.9           0.2  Iris-setosa
# 27  28            5.2           3.5            1.5           0.2  Iris-setosa
# 30  31            4.8           3.1            1.6           0.2  Iris-setosa
# 33  34            5.5           4.2            1.4           0.2  Iris-setosa

# %%
df.loc[ : ,["Id","SepalLengthCm","PetalWidthCm"]]
# Out:
#       Id  SepalLengthCm  PetalWidthCm
# 0      1            5.1           0.2
# 1      2            4.9           0.2
# 2      3            4.7           0.2
# 3      4            4.6           0.2
# 4      5            5.0           0.2
# ..   ...            ...           ...
# 145  146            6.7           2.3
# 146  147            6.3           1.9
# 147  148            6.5           2.0
# 148  149            6.2           2.3
# 149  150            5.9           1.8
#
# [150 rows x 3 columns]

# %%
df.loc[ : ,["Id","PetalWidthCm","Species"]]
# Out:
#       Id  PetalWidthCm         Species
# 0      1           0.2     Iris-setosa
# 1      2           0.2     Iris-setosa
# 2      3           0.2     Iris-setosa
# 3      4           0.2     Iris-setosa
# 4      5           0.2     Iris-setosa
# ..   ...           ...             ...
# 145  146           2.3  Iris-virginica
# 146  147           1.9  Iris-virginica
# 147  148           2.0  Iris-virginica
# 148  149           2.3  Iris-virginica
# 149  150           1.8  Iris-virginica
#
# [150 rows x 3 columns]

# %%
df.iloc[:7,:]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa

# %%
df.iloc[7]
# Out:
# Id                         8
# SepalLengthCm            5.0
# SepalWidthCm             3.4
# PetalLengthCm            1.5
# PetalWidthCm             0.2
# Species          Iris-setosa
# Name: 7, dtype: object

# %%
df.iloc[:7]
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
# 5   6            5.4           3.9            1.7           0.4  Iris-setosa
# 6   7            4.6           3.4            1.4           0.3  Iris-setosa

# %%
df.iloc[:4,:3]
# Out:
#    Id  SepalLengthCm  SepalWidthCm
# 0   1            5.1           3.5
# 1   2            4.9           3.0
# 2   3            4.7           3.2
# 3   4            4.6           3.1

# %%
df.iloc[:,1:5]
# Out:
#      SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0              5.1           3.5            1.4           0.2
# 1              4.9           3.0            1.4           0.2
# 2              4.7           3.2            1.3           0.2
# 3              4.6           3.1            1.5           0.2
# 4              5.0           3.6            1.4           0.2
# ..             ...           ...            ...           ...
# 145            6.7           3.0            5.2           2.3
# 146            6.3           2.5            5.0           1.9
# 147            6.5           3.0            5.2           2.0
# 148            6.2           3.4            5.4           2.3
# 149            5.9           3.0            5.1           1.8
#
# [150 rows x 4 columns]

# %%
df.iloc[7:14 , 0:3]
# Out:
#     Id  SepalLengthCm  SepalWidthCm
# 7    8            5.0           3.4
# 8    9            4.4           2.9
# 9   10            4.9           3.1
# 10  11            5.4           3.7
# 11  12            4.8           3.4
# 12  13            4.8           3.0
# 13  14            4.3           3.0

# %%
df.iloc[[5,45,55],:4]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm
# 5    6            5.4           3.9            1.7
# 45  46            4.8           3.0            1.4
# 55  56            5.7           2.8            4.5

# %%
df.iloc[[23,34,45],[0,5]]
# Out:
#     Id      Species
# 23  24  Iris-setosa
# 34  35  Iris-setosa
# 45  46  Iris-setosa

# %%
df.iloc[[23,76,87],:]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 23  24            5.1           3.3            1.7           0.5
# 76  77            6.8           2.8            4.8           1.4
# 87  88            6.3           2.3            4.4           1.3
#
#             Species
# 23      Iris-setosa
# 76  Iris-versicolor
# 87  Iris-versicolor

# %%
df.iloc[2:22,:]
# Out:
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 2    3            4.7           3.2            1.3           0.2  Iris-setosa
# 3    4            4.6           3.1            1.5           0.2  Iris-setosa
# 4    5            5.0           3.6            1.4           0.2  Iris-setosa
# 5    6            5.4           3.9            1.7           0.4  Iris-setosa
# 6    7            4.6           3.4            1.4           0.3  Iris-setosa
# 7    8            5.0           3.4            1.5           0.2  Iris-setosa
# 8    9            4.4           2.9            1.4           0.2  Iris-setosa
# 9   10            4.9           3.1            1.5           0.1  Iris-setosa
# 10  11            5.4           3.7            1.5           0.2  Iris-setosa
# 11  12            4.8           3.4            1.6           0.2  Iris-setosa
# 12  13            4.8           3.0            1.4           0.1  Iris-setosa
# ...

# %%
df.iloc[2:6,2:4]
# Out:
#    SepalWidthCm  PetalLengthCm
# 2           3.2            1.3
# 3           3.1            1.5
# 4           3.6            1.4
# 5           3.9            1.7

# %%
df.iloc[:,1:3]
# Out:
#      SepalLengthCm  SepalWidthCm
# 0              5.1           3.5
# 1              4.9           3.0
# 2              4.7           3.2
# 3              4.6           3.1
# 4              5.0           3.6
# ..             ...           ...
# 145            6.7           3.0
# 146            6.3           2.5
# 147            6.5           3.0
# 148            6.2           3.4
# 149            5.9           3.0
#
# [150 rows x 2 columns]

# %%
df.head(1)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa

# %%
df.iloc[2,4]
# Out:
# 0.2

# %%
df.head(4)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa

# %%
df.iloc[1,3]
# Out:
# 1.4

# %%
df.iloc[2,2]
# Out:
# 3.2

# %%
df['SepalWidthCm'].iloc[5]
# Out:
# 3.9

# %%
df["PetalLengthCm"].iloc[3]
# Out:
# 1.5

# %%
cols_2_4 = df.columns[2:4]

# %%
cols_2_4
# Out:
# Index(['SepalWidthCm', 'PetalLengthCm'], dtype='object')

# %%
df[cols_2_4]
# Out:
#      SepalWidthCm  PetalLengthCm
# 0             3.5            1.4
# 1             3.0            1.4
# 2             3.2            1.3
# 3             3.1            1.5
# 4             3.6            1.4
# ..            ...            ...
# 145           3.0            5.2
# 146           2.5            5.0
# 147           3.0            5.2
# 148           3.4            5.4
# 149           3.0            5.1
#
# [150 rows x 2 columns]

# %%
df[df.columns[2:4]].iloc[5:10]
# Out:
#    SepalWidthCm  PetalLengthCm
# 5           3.9            1.7
# 6           3.4            1.4
# 7           3.4            1.5
# 8           2.9            1.4
# 9           3.1            1.5

# %%
# df.isnull()

# %%
# df.isna()

# %%
# df.isna().head(5)

# %%
df.isnull().any()
# Out:
# Id               False
# SepalLengthCm    False
# SepalWidthCm     False
# PetalLengthCm    False
# PetalWidthCm     False
# Species          False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.isnull().sum(axis=1)
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    0
# 146    0
# 147    0
# 148    0
# 149    0
# Length: 150, dtype: int64

# %%
df.isnull().sum(axis=0)
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
# df.groupby(['Gender'])['Score'].apply(lambda x:x.ianull().sum())

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df['PetalLengthCm'] = df['PetalLengthCm'].astype("int")

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm      int32
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
pip install -U scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from sklearn import preprocessing

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5              1           0.2  Iris-setosa
# 1   2            4.9           3.0              1           0.2  Iris-setosa
# 2   3            4.7           3.2              1           0.2  Iris-setosa
# 3   4            4.6           3.1              1           0.2  Iris-setosa
# 4   5            5.0           3.6              1           0.2  Iris-setosa

# %%
min_max_scaler = preprocessing.MinMaxScaler()

# %%
x = df.iloc[: , :4]

# %%
x_scaled = min_max_scaler.fit_transform(x)

# %%
df_normalized = pd.DataFrame(x_scaled)

# %%
df_normalized
# Out:
#             0         1         2    3
# 0    0.000000  0.222222  0.625000  0.0
# 1    0.006711  0.166667  0.416667  0.0
# 2    0.013423  0.111111  0.500000  0.0
# 3    0.020134  0.083333  0.458333  0.0
# 4    0.026846  0.194444  0.666667  0.0
# ..        ...       ...       ...  ...
# 145  0.973154  0.666667  0.416667  0.8
# 146  0.979866  0.555556  0.208333  0.8
# 147  0.986577  0.611111  0.416667  0.8
# 148  0.993289  0.527778  0.583333  0.8
# 149  1.000000  0.444444  0.416667  0.8
#
# [150 rows x 4 columns]

# %% [markdown]
# # Lable Encoding

# %%
df['Species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
df['Species'] = label_encoder.fit_transform(df['Species'])

# %%
df['Species'].unique()
# Out:
# array([0, 1, 2])

# %%
df.head(5)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0   1            5.1           3.5              1           0.2        0
# 1   2            4.9           3.0              1           0.2        0
# 2   3            4.7           3.2              1           0.2        0
# 3   4            4.6           3.1              1           0.2        0
# 4   5            5.0           3.6              1           0.2        0

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5              1           0.2        0
# 1      2            4.9           3.0              1           0.2        0
# 2      3            4.7           3.2              1           0.2        0
# 3      4            4.6           3.1              1           0.2        0
# 4      5            5.0           3.6              1           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0              5           2.3        2
# 146  147            6.3           2.5              5           1.9        2
# 147  148            6.5           3.0              5           2.0        2
# 148  149            6.2           3.4              5           2.3        2
# 149  150            5.9           3.0              5           1.8        2
#
# [150 rows x 6 columns]

# %% [markdown]
# # One-Hot Encoding

# %%
df['Species'].unique()
# Out:
# array([0, 1, 2])

# %%
features_df = df.drop(columns=['Species'])

# %%
enc = preprocessing.OneHotEncoder()

# %%
enc_df = enc.fit_transform(df[['Species']])

# %%
enc_df
# Out:
# <150x3 sparse matrix of type '<class 'numpy.float64'>'
# 	with 150 stored elements in Compressed Sparse Row format>

# %%
enc_df = pd.DataFrame(enc_df)

# %%
enc_df
# Out:
#                  0
# 0      (0, 0)\t1.0
# 1      (0, 0)\t1.0
# 2      (0, 0)\t1.0
# 3      (0, 0)\t1.0
# 4      (0, 0)\t1.0
# ..             ...
# 145    (0, 2)\t1.0
# 146    (0, 2)\t1.0
# 147    (0, 2)\t1.0
# 148    (0, 2)\t1.0
# 149    (0, 2)\t1.0
#
# [150 rows x 1 columns]

# %%
enc_df = toarray(enc_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 enc_df = toarray(enc_df)
#
# NameError: name 'toarray' is not defined

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1            5.1           3.5              1           0.2        0
# 1      2            4.9           3.0              1           0.2        0
# 2      3            4.7           3.2              1           0.2        0
# 3      4            4.6           3.1              1           0.2        0
# 4      5            5.0           3.6              1           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146            6.7           3.0              5           2.3        2
# 146  147            6.3           2.5              5           1.9        2
# 147  148            6.5           3.0              5           2.0        2
# 148  149            6.2           3.4              5           2.3        2
# 149  150            5.9           3.0              5           1.8        2
#
# [150 rows x 6 columns]

# %%
col = ["SepalLengthCm",	"SepalWidthCm"	,"PetalLengthCm",	"PetalWidthCm"]

# %%
df.boxplot(col)
# Out:
# <Axes: >
