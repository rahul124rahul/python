# %%
import pandas as pd

# %%
import numpy as nm

# %%
df = pd.read_csv("student_performance.csv")

# %%
df
# Out:
#     math_score  reading_score  writing_score   placement_score  \
# 0         70.0           82.0           70.0              97.0
# 1         61.0           91.0           77.0               NaN
# 2         78.0           75.0           67.0              87.0
# 3         65.0           78.0           66.0              75.0
# 4         64.0            NaN           76.0              93.0
# 5         70.0           78.0           76.0              79.0
# 6         78.0           75.0           75.0              95.0
# 7         73.0           75.0           74.0              85.0
# 8          NaN           85.0           67.0              90.0
# 9         73.0           87.0           60.0             100.0
# 10        79.0           90.0           75.0              85.0
# 11        62.0           94.0           77.0              79.0
# 12        72.0           80.0           71.0              77.0
# 13        78.0           91.0           69.0              98.0
# ...

# %%
df.isnull()
# Out:
#     math_score  reading_score  writing_score   placement_score  \
# 0        False          False          False             False
# 1        False          False          False              True
# 2        False          False          False             False
# 3        False          False          False             False
# 4        False           True          False             False
# 5        False          False          False             False
# 6        False          False          False             False
# 7        False          False          False             False
# 8         True          False          False             False
# 9        False          False          False             False
# 10       False          False          False             False
# 11       False          False          False             False
# 12       False          False          False             False
# 13       False          False          False             False
# ...

# %%
df.notnull()
# Out:
#     math_score  reading_score  writing_score   placement_score  \
# 0         True           True           True              True
# 1         True           True           True             False
# 2         True           True           True              True
# 3         True           True           True              True
# 4         True          False           True              True
# 5         True           True           True              True
# 6         True           True           True              True
# 7         True           True           True              True
# 8        False           True           True              True
# 9         True           True           True              True
# 10        True           True           True              True
# 11        True           True           True              True
# 12        True           True           True              True
# 13        True           True           True              True
# ...

# %%
df
# Out:
#     math_score  reading_score  writing_score   placement_score  \
# 0         70.0           82.0           70.0              97.0
# 1         61.0           91.0           77.0               NaN
# 2         78.0           75.0           67.0              87.0
# 3         65.0           78.0           66.0              75.0
# 4         64.0            NaN           76.0              93.0
# 5         70.0           78.0           76.0              79.0
# 6         78.0           75.0           75.0              95.0
# 7         73.0           75.0           74.0              85.0
# 8          NaN           85.0           67.0              90.0
# 9         73.0           87.0           60.0             100.0
# 10        79.0           90.0           75.0              85.0
# 11        62.0           94.0           77.0              79.0
# 12        72.0           80.0           71.0              77.0
# 13        78.0           91.0           69.0              98.0
# ...

# %%
series = pd.notnull(df)

# %%
series
# Out:
#     math_score  reading_score  writing_score   placement_score  \
# 0         True           True           True              True
# 1         True           True           True             False
# 2         True           True           True              True
# 3         True           True           True              True
# 4         True          False           True              True
# 5         True           True           True              True
# 6         True           True           True              True
# 7         True           True           True              True
# 8        False           True           True              True
# 9         True           True           True              True
# 10        True           True           True              True
# 11        True           True           True              True
# 12        True           True           True              True
# 13        True           True           True              True
# ...

# %%
s1 = pd.isnull(df)

# %%
s1
# Out:
#     math_score  reading_score  writing_score   placement_score  \
# 0        False          False          False             False
# 1        False          False          False              True
# 2        False          False          False             False
# 3        False          False          False             False
# 4        False           True          False             False
# 5        False          False          False             False
# 6        False          False          False             False
# 7        False          False          False             False
# 8         True          False          False             False
# 9        False          False          False             False
# 10       False          False          False             False
# 11       False          False          False             False
# 12       False          False          False             False
# 13       False          False          False             False
# ...

# %%
df[s1]
# Out:
#     math_score  reading_score  writing_score   placement_score  \
# 0          NaN            NaN            NaN               NaN
# 1          NaN            NaN            NaN               NaN
# 2          NaN            NaN            NaN               NaN
# 3          NaN            NaN            NaN               NaN
# 4          NaN            NaN            NaN               NaN
# 5          NaN            NaN            NaN               NaN
# 6          NaN            NaN            NaN               NaN
# 7          NaN            NaN            NaN               NaN
# 8          NaN            NaN            NaN               NaN
# 9          NaN            NaN            NaN               NaN
# 10         NaN            NaN            NaN               NaN
# 11         NaN            NaN            NaN               NaN
# 12         NaN            NaN            NaN               NaN
# 13         NaN            NaN            NaN               NaN
# ...

# %%
s2 = pd.isnull(df["math_score"])

# %%
df[s2]
# Out:
#    math_score  reading_score  writing_score   placement_score  club_join_date  \
# 8         NaN           85.0           67.0              90.0          2018.0
#
#    placement_offer_count
# 8                      3

# %%
s2 = pd.isnull(df[:])

# %%
df[s2]
# Out:
#     math_score  reading_score  writing_score   placement_score  \
# 0          NaN            NaN            NaN               NaN
# 1          NaN            NaN            NaN               NaN
# 2          NaN            NaN            NaN               NaN
# 3          NaN            NaN            NaN               NaN
# 4          NaN            NaN            NaN               NaN
# 5          NaN            NaN            NaN               NaN
# 6          NaN            NaN            NaN               NaN
# 7          NaN            NaN            NaN               NaN
# 8          NaN            NaN            NaN               NaN
# 9          NaN            NaN            NaN               NaN
# 10         NaN            NaN            NaN               NaN
# 11         NaN            NaN            NaN               NaN
# 12         NaN            NaN            NaN               NaN
# 13         NaN            NaN            NaN               NaN
# ...

# %%
df.isnull().values.any()
# Out:
# True

# %%
df.isnull().values
# Out:
# array([[False, False, False, False, False, False],
#        [False, False, False,  True, False, False],
#        [False, False, False, False, False, False],
#        [False, False, False, False, False, False],
#        [False,  True, False, False, False, False],
#        [False, False, False, False, False, False],
#        [False, False, False, False, False, False],
#        [False, False, False, False, False, False],
#        [ True, False, False, False, False, False],
#        [False, False, False, False, False, False],
#        [False, False, False, False,  True, False],
#        [False, False, False, False, False, False],
#        [False, False, False, False, False, False],
#        [False, False, False, False, False, False],
#        [False, False,  True, False, False, False],
#        [False, False, False, False, False, False],
#        [False, False, False, False, False, False],
#        [False, False, False, False, False, False],
# ...

# %%
ndf = df

# %%
ndf.fillna(0)
# Out:
#     math_score  reading_score  writing_score   placement_score  \
# 0         70.0           82.0           70.0              97.0
# 1         61.0           91.0           77.0               0.0
# 2         78.0           75.0           67.0              87.0
# 3         65.0           78.0           66.0              75.0
# 4         64.0            0.0           76.0              93.0
# 5         70.0           78.0           76.0              79.0
# 6         78.0           75.0           75.0              95.0
# 7         73.0           75.0           74.0              85.0
# 8          0.0           85.0           67.0              90.0
# 9         73.0           87.0           60.0             100.0
# 10        79.0           90.0           75.0              85.0
# 11        62.0           94.0           77.0              79.0
# 12        72.0           80.0           71.0              77.0
# 13        78.0           91.0           69.0              98.0
# ...

# %%
m_v = ndf["math_score"].mean()

# %%
ndf["math_score"].fillna(value=m_v , inplace=True)

# %%
ndf
# Out:
#     math_score  reading_score  writing_score   placement_score  \
# 0         70.0           82.0           70.0              97.0
# 1         61.0           91.0           77.0               NaN
# 2         78.0           75.0           67.0              87.0
# 3         65.0           78.0           66.0              75.0
# 4         64.0            NaN           76.0              93.0
# 5         70.0           78.0           76.0              79.0
# 6         78.0           75.0           75.0              95.0
# 7         73.0           75.0           74.0              85.0
# 8         70.2           85.0           67.0              90.0
# 9         73.0           87.0           60.0             100.0
# 10        79.0           90.0           75.0              85.0
# 11        62.0           94.0           77.0              79.0
# 12        72.0           80.0           71.0              77.0
# 13        78.0           91.0           69.0              98.0
# ...

# %%
ndf.replace(to_replace = nm.nan ,value = -9999999)
# Out:
#     math_score  reading_score  writing_score   placement_score  \
# 0         70.0           82.0           70.0              97.0
# 1         61.0           91.0           77.0        -9999999.0
# 2         78.0           75.0           67.0              87.0
# 3         65.0           78.0           66.0              75.0
# 4         64.0     -9999999.0           76.0              93.0
# 5         70.0           78.0           76.0              79.0
# 6         78.0           75.0           75.0              95.0
# 7         73.0           75.0           74.0              85.0
# 8         70.2           85.0           67.0              90.0
# 9         73.0           87.0           60.0             100.0
# 10        79.0           90.0           75.0              85.0
# 11        62.0           94.0           77.0              79.0
# 12        72.0           80.0           71.0              77.0
# 13        78.0           91.0           69.0              98.0
# ...

# %%
df
# Out:
#     math_score  reading_score  writing_score   placement_score  \
# 0         70.0           82.0           70.0              97.0
# 1         61.0           91.0           77.0               NaN
# 2         78.0           75.0           67.0              87.0
# 3         65.0           78.0           66.0              75.0
# 4         64.0            NaN           76.0              93.0
# 5         70.0           78.0           76.0              79.0
# 6         78.0           75.0           75.0              95.0
# 7         73.0           75.0           74.0              85.0
# 8         70.2           85.0           67.0              90.0
# 9         73.0           87.0           60.0             100.0
# 10        79.0           90.0           75.0              85.0
# 11        62.0           94.0           77.0              79.0
# 12        72.0           80.0           71.0              77.0
# 13        78.0           91.0           69.0              98.0
# ...

# %%
ndf.dropna()
# Out:
#     math_score  reading_score  writing_score   placement_score  \
# 0         70.0           82.0           70.0              97.0
# 2         78.0           75.0           67.0              87.0
# 3         65.0           78.0           66.0              75.0
# 5         70.0           78.0           76.0              79.0
# 6         78.0           75.0           75.0              95.0
# 7         73.0           75.0           74.0              85.0
# 8         70.2           85.0           67.0              90.0
# 9         73.0           87.0           60.0             100.0
# 11        62.0           94.0           77.0              79.0
# 12        72.0           80.0           71.0              77.0
# 13        78.0           91.0           69.0              98.0
# 15        75.0           76.0           70.0              99.0
# 16        67.0           89.0           77.0              86.0
# 17        71.0           78.0           74.0              91.0
# ...

# %%
ndf.dropna(axis=1)
# Out:
#     math_score  placement_offer_count
# 0         70.0                      1
# 1         61.0                      1
# 2         78.0                      3
# 3         65.0                      2
# 4         64.0                      3
# 5         70.0                      2
# 6         78.0                      3
# 7         73.0                      3
# 8         70.2                      3
# 9         73.0                      3
# 10        79.0                      3
# 11        62.0                      2
# 12        72.0                      2
# 13        78.0                      1
# 14        65.0                      2
# 15        75.0                      3
# 16        67.0                      3
# 17        71.0                      3
# 18        68.0                      2
# 19        78.0                      2
# 20        63.0                      3
# 21        63.0                      3
# 22        73.0                      2
# 23        69.0                      2
# ...

# %%
new_data = ndf.dropna(axis = 0, how ='any')
new_data
# Out:
#     math_score  reading_score  writing_score   placement_score  \
# 0         70.0           82.0           70.0              97.0
# 2         78.0           75.0           67.0              87.0
# 3         65.0           78.0           66.0              75.0
# 5         70.0           78.0           76.0              79.0
# 6         78.0           75.0           75.0              95.0
# 7         73.0           75.0           74.0              85.0
# 8         70.2           85.0           67.0              90.0
# 9         73.0           87.0           60.0             100.0
# 11        62.0           94.0           77.0              79.0
# 12        72.0           80.0           71.0              77.0
# 13        78.0           91.0           69.0              98.0
# 15        75.0           76.0           70.0              99.0
# 16        67.0           89.0           77.0              86.0
# 17        71.0           78.0           74.0              91.0
# ...

# %%
ndf
# Out:
#     math_score  reading_score  writing_score   placement_score  \
# 0         70.0           82.0           70.0              97.0
# 2         78.0           75.0           67.0              87.0
# 3         65.0           78.0           66.0              75.0
# 5         70.0           78.0           76.0              79.0
# 6         78.0           75.0           75.0              95.0
# 7         73.0           75.0           74.0              85.0
# 8         70.2           85.0           67.0              90.0
# 9         73.0           87.0           60.0             100.0
# 11        62.0           94.0           77.0              79.0
# 12        72.0           80.0           71.0              77.0
# 13        78.0           91.0           69.0              98.0
# 15        75.0           76.0           70.0              99.0
# 16        67.0           89.0           77.0              86.0
# 17        71.0           78.0           74.0              91.0
# ...

# %%
ndf
# Out:
#     math_score  reading_score  writing_score   placement_score  \
# 0         70.0           82.0           70.0              97.0
# 2         78.0           75.0           67.0              87.0
# 3         65.0           78.0           66.0              75.0
# 5         70.0           78.0           76.0              79.0
# 6         78.0           75.0           75.0              95.0
# 7         73.0           75.0           74.0              85.0
# 8         70.2           85.0           67.0              90.0
# 9         73.0           87.0           60.0             100.0
# 11        62.0           94.0           77.0              79.0
# 12        72.0           80.0           71.0              77.0
# 13        78.0           91.0           69.0              98.0
# 15        75.0           76.0           70.0              99.0
# 16        67.0           89.0           77.0              86.0
# 17        71.0           78.0           74.0              91.0
# ...

# %%
col = ["math_score" , "reading_score" , "writing_score", "placement_score"]

# %%
df.boxplot(col)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df.boxplot(col)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:529, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     512 @Substitution(data="", backend=_backend_doc)
#     513 @Appender(_boxplot_doc)
#     514 def boxplot_frame(
#    (...)
#     526     **kwargs,
#     527 ):
#     528     plot_backend = _get_plot_backend(backend)
# --> 529     return plot_backend.boxplot_frame(
#     530         self,
#     531         column=column,
#     532         by=by,
#     533         ax=ax,
#     534         fontsize=fontsize,
#     535         rot=rot,
#     536         grid=grid,
#     537         figsize=figsize,
#     538         layout=layout,
#     539         return_type=return_type,
# ...

# %%
df
# Out:
#     math_score  reading_score  writing_score   placement_score  \
# 0         70.0           82.0           70.0              97.0
# 1         61.0           91.0           77.0               NaN
# 2         78.0           75.0           67.0              87.0
# 3         65.0           78.0           66.0              75.0
# 4         64.0            NaN           76.0              93.0
# 5         70.0           78.0           76.0              79.0
# 6         78.0           75.0           75.0              95.0
# 7         73.0           75.0           74.0              85.0
# 8         70.2           85.0           67.0              90.0
# 9         73.0           87.0           60.0             100.0
# 10        79.0           90.0           75.0              85.0
# 11        62.0           94.0           77.0              79.0
# 12        72.0           80.0           71.0              77.0
# 13        78.0           91.0           69.0              98.0
# ...

# %%
df.fillna(0)
# Out:
#     math_score  reading_score  writing_score   placement_score  \
# 0         70.0           82.0           70.0              97.0
# 1         61.0           91.0           77.0               0.0
# 2         78.0           75.0           67.0              87.0
# 3         65.0           78.0           66.0              75.0
# 4         64.0            0.0           76.0              93.0
# 5         70.0           78.0           76.0              79.0
# 6         78.0           75.0           75.0              95.0
# 7         73.0           75.0           74.0              85.0
# 8         70.2           85.0           67.0              90.0
# 9         73.0           87.0           60.0             100.0
# 10        79.0           90.0           75.0              85.0
# 11        62.0           94.0           77.0              79.0
# 12        72.0           80.0           71.0              77.0
# 13        78.0           91.0           69.0              98.0
# ...

# %%
df.boxplot(col)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 df.boxplot(col)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:529, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     512 @Substitution(data="", backend=_backend_doc)
#     513 @Appender(_boxplot_doc)
#     514 def boxplot_frame(
#    (...)
#     526     **kwargs,
#     527 ):
#     528     plot_backend = _get_plot_backend(backend)
# --> 529     return plot_backend.boxplot_frame(
#     530         self,
#     531         column=column,
#     532         by=by,
#     533         ax=ax,
#     534         fontsize=fontsize,
#     535         rot=rot,
#     536         grid=grid,
#     537         figsize=figsize,
#     538         layout=layout,
#     539         return_type=return_type,
# ...

# %%
dff = pd.read_csv("student_performance.csv")

# %%
dff
# Out:
#     math_score  reading_score  writing_score   placement_score  \
# 0         70.0           82.0           70.0              97.0
# 1         61.0           91.0           77.0               NaN
# 2         78.0           75.0           67.0              87.0
# 3         65.0           78.0           66.0              75.0
# 4         64.0            NaN           76.0              93.0
# 5         70.0           78.0           76.0              79.0
# 6         78.0           75.0           75.0              95.0
# 7         73.0           75.0           74.0              85.0
# 8          NaN           85.0           67.0              90.0
# 9         73.0           87.0           60.0             100.0
# 10        79.0           90.0           75.0              85.0
# 11        62.0           94.0           77.0              79.0
# 12        72.0           80.0           71.0              77.0
# 13        78.0           91.0           69.0              98.0
# ...

# %%
dff.dropna()
# Out:
#     math_score  reading_score  writing_score   placement_score  \
# 0         70.0           82.0           70.0              97.0
# 2         78.0           75.0           67.0              87.0
# 3         65.0           78.0           66.0              75.0
# 5         70.0           78.0           76.0              79.0
# 6         78.0           75.0           75.0              95.0
# 7         73.0           75.0           74.0              85.0
# 9         73.0           87.0           60.0             100.0
# 11        62.0           94.0           77.0              79.0
# 12        72.0           80.0           71.0              77.0
# 13        78.0           91.0           69.0              98.0
# 15        75.0           76.0           70.0              99.0
# 16        67.0           89.0           77.0              86.0
# 17        71.0           78.0           74.0              91.0
# 18        68.0           78.0           75.0              79.0
# ...

# %%
coll = ["math_score",	"reading_score",	"writing_score"]

# %%
dff.boxplot(coll)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 dff.boxplot(coll)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:529, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     512 @Substitution(data="", backend=_backend_doc)
#     513 @Appender(_boxplot_doc)
#     514 def boxplot_frame(
#    (...)
#     526     **kwargs,
#     527 ):
#     528     plot_backend = _get_plot_backend(backend)
# --> 529     return plot_backend.boxplot_frame(
#     530         self,
#     531         column=column,
#     532         by=by,
#     533         ax=ax,
#     534         fontsize=fontsize,
#     535         rot=rot,
#     536         grid=grid,
#     537         figsize=figsize,
#     538         layout=layout,
#     539         return_type=return_type,
# ...

# %%
print(nm.where(df['math score']>90))
print(nm.where(df['reading score']<25))
print(nm.where(df['writing score']<30))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'math score'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 print(nm.where(df['math score']>90))
# ...
