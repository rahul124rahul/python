# %% [markdown]
# # Practical No 4

# %% [markdown]
# # Data Analysis of Boston house Prices Dataset

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
boston = pd.read_csv("BostonHousing.csv")
# boston.index.name = None

# %%
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
boston.head(2)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
#
#        b  lstat  medv
# 0  396.9   4.98  24.0
# 1  396.9   9.14  21.6

# %%
boston.tail()
# Out:
#         crim   zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273     21.0
# 502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273     21.0
# 503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273     21.0
# 504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273     21.0
# 505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273     21.0
#
#           b  lstat  medv
# 501  391.99   9.67  22.4
# 502  396.90   9.08  20.6
# 503  396.90   5.64  23.9
# 504  393.45   6.48  22.0
# 505  396.90   7.88  11.9

# %%
boston.shape
# Out:
# (506, 14)

# %%
boston.isnull().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
boston.notnull().sum()
# Out:
# crim       506
# zn         506
# indus      506
# chas       506
# nox        506
# rm         506
# age        506
# dis        506
# rad        506
# tax        506
# ptratio    506
# b          506
# lstat      506
# medv       506
# dtype: int64

# %%
boston.medv
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
sns.scatterplot(x = 'rm',y = 'medv',data = boston)
# Out:
# <Axes: xlabel='rm', ylabel='medv'>

# %%
for col in boston.columns:
    boston[col].fillna(value=boston[col].mean(),inplace=True)

# %%
boston.isna().sum()
# Out:
# crim       0
# zn         0
# indus      0
# chas       0
# nox        0
# rm         0
# age        0
# dis        0
# rad        0
# tax        0
# ptratio    0
# b          0
# lstat      0
# medv       0
# dtype: int64

# %%
sns.histplot(x='rm' , data=boston , kde=True)
# Out:
# <Axes: xlabel='rm', ylabel='Count'>

# %%
sns.heatmap(boston.corr().abs(),annot=True)
plt.figure(figsize=(20,10))
plt.show()

# %%
X = boston[['rm']]
X[:300] #dataFrame
# Out:
#         rm
# 0    6.575
# 1    6.421
# 2    7.185
# 3    6.998
# 4    7.147
# ..     ...
# 295  6.678
# 296  6.549
# 297  5.790
# 298  6.345
# 299  7.041
#
# [300 rows x 1 columns]

# %%
y = boston['medv']
y[:300] #Series/Array
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 295    28.6
# 296    27.1
# 297    20.3
# 298    22.5
# 299    29.0
# Name: medv, Length: 300, dtype: float64

# %%
# Importing, Calling the Algorithm and create an object of it
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()

# %%
model.fit(X,y) #algorithm will understand the pattern + will calculate m and c
# Out:
# LinearRegression()

# %%
# predict the house price using rm feature
model.predict([[7.147]])
# Out:
# C:\Users\rahul\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([30.38215211])

# %%
test_data = [[5.983],[5.926],[6.312],[7.061]]
test_data
# Out:
# [[5.983], [5.926], [6.312], [7.061]]

# %%
# now lest apply prediction on test data
model.predict(test_data)
# Out:
# C:\Users\rahul\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([19.78729726, 19.26847705, 22.78189111, 29.59937074])

# %%
# Now lets check pattern of Training and testing data
sns.scatterplot(x = 'rm',y = 'medv',data = boston)
plt.plot(test_data,y_pred,'r--')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 3
#       1 # Now lets check pattern of Training and testing data
#       2 sns.scatterplot(x = 'rm',y = 'medv',data = boston)
# ----> 3 plt.plot(test_data,y_pred,'r--')
#
# NameError: name 'y_pred' is not defined

# %%
y_pred = model.predict(test_data)
y_pred
# Out:
# C:\Users\rahul\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([19.78729726, 19.26847705, 22.78189111, 29.59937074])

# %%
model.score(X,y)*100
# Out:
# 48.35254559913342

# %%
x = 5

# %%
# m value
m = model.coef_
m
# Out:
# array([9.10210898])

# %%
# c value
c = model.intercept_
c
# Out:
# -34.670620776438554

# %%
m*x+c
# Out:
# array([10.83992413])

# %%
# now ur equation is formed,... we can supply different inputs
m*19 + c
# Out:
# array([138.26944987])
